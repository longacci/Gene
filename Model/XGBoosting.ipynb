# 2     6.770716  7.323996  8.276253  6.527094  6.677929   6.691402  6.671845
# 3     7.283117  6.630636  7.892145  6.487721  6.528980   6.487721  6.599425
# 4     6.938120  7.127580  7.851027  6.469428  6.718180   6.392738  6.531331
# ...        ...       ...       ...       ...       ...        ...       ...
# 1037  7.835880  6.778497  7.747274  6.502977  6.745285   6.551610  6.701982
# 1038  7.158885  7.107113  7.971264  6.355886  6.741811   6.576480  6.664663
# 1039  7.454734  6.917895  7.668293  6.561785  6.831080   6.593668  6.642215
# 1040  7.566920  6.962266  7.698907  6.575676  6.661368   6.632561  6.601802
# 1041  7.580032  6.957571  7.476737  6.458386  6.684585   6.714125  6.634755
#
# [1042 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df_important,y,test_size=0.1,random_state=11,stratify=y,shuffle=True)
print(f"Train shape:{x_train.shape}")
print(f"Test shape:{x_test.shape}")
# Out:
# Train shape:(937, 24)
# Test shape:(105, 24)

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x_train_sc = scale.fit_transform(x_train)
x_test_sc = scale.transform(x_test)

# %%
list_feature = feature['Gene']
list_feature
# Out:
# 0          IL18
# 1        FER1L3
# 2      AL157484
# 3        VPS13C
# 4     LOC653591
# 5         IL2RB
# 6         ABCA1
# 7        ERVWE1
# 8          LDLR
# 9         SYTL3
# 10      SLC40A1
# 11         BRI3
# 12        CDAN1
# 13        OLIG2
# 14        STAU2
# 15     MGC24103
# 16       RNF165
# 17     BC080552
# 18     AK124771
# 19        GPR97
# 20        SSTR5
# 21        MYO5C
# 22    LOC730656
# 23         NRG1
# Name: Gene, dtype: object

# %%
ranks = []
for i in range(len(list_feature)):
    arr = []
    for j in range(i+1):
        arr.append(list_feature[j])
    ranks.append(arr)
ranks
# Out:
# [['IL18'],
#  ['IL18', 'FER1L3'],
#  ['IL18', 'FER1L3', 'AL157484'],
#  ['IL18', 'FER1L3', 'AL157484', 'VPS13C'],
#  ['IL18', 'FER1L3', 'AL157484', 'VPS13C', 'LOC653591'],
#  ['IL18', 'FER1L3', 'AL157484', 'VPS13C', 'LOC653591', 'IL2RB'],
#  ['IL18', 'FER1L3', 'AL157484', 'VPS13C', 'LOC653591', 'IL2RB', 'ABCA1'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97',
#   'SSTR5'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97',
#   'SSTR5',
#   'MYO5C'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97',
#   'SSTR5',
#   'MYO5C',
#   'LOC730656'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97',
#   'SSTR5',
#   'MYO5C',
#   'LOC730656',
#   'NRG1']]

# %%
from sklearn.metrics import confusion_matrix,roc_auc_score
def confusion_matrix_scorer(clf=None,X=None, y=None,y_pred=None,y_prob=None):
    if clf != None:
        y_pred = clf.predict(X)
        y_prob = clf.predict_proba(X)[:,1]
    auc = roc_auc_score(y,y_prob)
    tn,fp,fn,tp = confusion_matrix(y,y_pred).ravel()
    acc = (tp+tn) / (tp+fp+fn+tn)
    precision = tp/(tp+fp)
    specificity = tn/(tn+fp)
    sensitivity = tp / (tp+fn)
    f1_score = (2*tp)/(2*tp+fp+fn)
    return {'acc':acc,'precision':precision,'specificity':specificity,'sensitivity':sensitivity,'f1_score':f1_score,'auc':auc}

# %%
NUMBER_FOLD = 4
def create_df_val(rank,rs_cv):
    df_val = {
        "ACC":[],
        "precision":[],
        "specificity":[],
        "sensitivity":[],
        "f1_score":[],
        "AUC":[],
        "params":[]
    }
    for i in range(NUMBER_FOLD):
        str_label = f"split{i}"
        df_val["ACC"].append(np.array(rs_cv[str_label+"_test_acc"]))
        df_val["precision"].append(rs_cv[str_label+"_test_precision"])
        df_val["specificity"].append(rs_cv[str_label+"_test_specificity"])
        df_val["sensitivity"].append(rs_cv[str_label+"_test_sensitivity"])
        df_val["f1_score"].append(rs_cv[str_label+"_test_f1_score"])
        df_val["AUC"].append(rs_cv[str_label+"_test_auc"])
        df_val["params"].append(rs_cv["params"])
    df_val["ACC"] = np.array(df_val["ACC"] ).flatten()
    df_val["precision"] = np.array(df_val["precision"] ).flatten()
    df_val["specificity"] = np.array(df_val["specificity"] ).flatten()
    df_val["sensitivity"] = np.array(df_val["sensitivity"] ).flatten()
    df_val["f1_score"] = np.array(df_val["f1_score"] ).flatten()
    df_val["AUC"] = np.array(df_val["AUC"] ).flatten()
    df_val["params"] = np.array(df_val["params"] ).flatten()
    df_combine_val = pd.DataFrame(df_val).dropna(axis=0).sort_values(by="ACC",ascending=False)
    if df_combine_val.shape[0]>0:
        gene_top =  df_combine_val.iloc[0,:].values
        return [rank,gene_top[0],gene_top[1],gene_top[2],gene_top[3],gene_top[4],gene_top[5],gene_top[6]]
    else:
        return []

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV,StratifiedShuffleSplit

model = XGBClassifier(random_state=11)
params = {
    'n_estimators': [100, 200, 300, 400, 500, 1000],
    'max_depth': [3, 4, 5, 6],
    'learning_rate': [0.1, 0.01, 0.001],
    'subsample': [0.5, 0.7],
}
ss = StratifiedShuffleSplit(n_splits=NUMBER_FOLD,test_size=0.3,random_state=11)
grid_search = GridSearchCV(estimator=model, param_grid=params, 
                              cv=ss, verbose=2, return_train_score=True,refit=False,scoring=confusion_matrix_scorer)
ls_result = []
for i,rank in enumerate(ranks):
    grid_model = grid_search.fit(x_train_sc[:,:i+1],y_train)
    rs_cv = grid_model.cv_results_
    ls_result.append(create_df_val(rank,rs_cv))

# %%
df_result_val = pd.DataFrame(ls_result)
df_result_val.columns = ["Gene","ACC","Precision","Sp","Sn","F1_score","AUC","Params"]
df_result_val.iloc[:,1:7] = round(df_result_val.iloc[:,1:7] * 100,2)
df_result_val
# Out:
#                                                  Gene   ACC  Precision     Sp  \
# 0                                          [SLC25A20]  66.4      56.47  76.13
# 1                                    [SLC25A20, DMKN]  66.0      57.81  82.58
# 2                             [SLC25A20, DMKN, MFSD4]  68.8      64.41  86.45
# 3                   [SLC25A20, DMKN, MFSD4, KIAA1407]  72.0      70.49  88.39
# 4            [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J]  75.2      72.00  86.45
# 5      [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2]  74.0      72.06  87.74
# 6   [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  73.6      67.47  82.58
# 7   [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.4      68.67  83.23
# 8   [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  73.6      75.44  90.97
# 9   [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.0      68.75  83.87
# 10  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.0      67.86  82.58
# 11  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.4      67.82  81.94
# 12  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  76.0      71.08  84.52
# 13  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  75.2      72.60  87.10
# 14  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.8      68.60  82.58
# 15  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  77.2      73.17  85.81
# 16  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  77.6      71.91  83.87
# 17  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  78.4      73.56  85.16
# 18  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  79.2      74.16  85.16
# 19  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  79.6      73.91  84.52
# 20  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  79.2      73.12  83.87
# 21  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  79.2      73.63  84.52
# 22  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  80.4      76.74  87.10
# 23  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  80.4      76.74  87.10
# 24  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  81.2      76.09  85.81
# 25  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  81.2      76.67  86.45
# 26  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  86.4      82.80  89.68
# 27  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  85.2      81.52  89.03
# 28  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  85.6      83.91  90.97
# 29  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  86.4      83.52  90.32
# 30  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  86.4      83.52  90.32
# 31  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  85.2      81.52  89.03
# 32  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  85.2      81.52  89.03
# 33  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  87.2      88.89  94.19
# 34  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  86.8      87.80  93.55
# 35  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  86.8      87.80  93.55
# 36  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  86.4      87.65  93.55
# 37  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  86.8      86.05  92.26
# 38  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  87.6      89.02  94.19
# 39  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  88.8      87.64  92.90
# 40  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  89.2      90.48  94.84
# 41  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  88.8      89.41  94.19
# 42  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  89.6      88.76  93.55
# 43  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  90.0      89.77  94.19
# 44  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  89.2      89.53  94.19
# 45  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  88.8      88.51  93.55
# 46  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  88.4      87.50  92.90
# 47  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  88.0      88.24  93.55
# 48  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  88.0      86.52  92.26
# 49  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  88.8      89.41  94.19
# 50  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  88.4      88.37  93.55
#
#        Sn  F1_score    AUC                                             Params
# 0   50.53     53.33  63.78  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 1   38.95     46.54  67.46  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...
# 2   40.00     49.35  67.67  {'learning_rate': 0.001, 'max_depth': 5, 'n_es...
# 3   45.26     55.13  71.99  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...
# 4   56.84     63.53  77.70  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...
# 5   51.58     60.12  76.90  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...
# 6   58.95     62.92  75.49  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 7   60.00     64.04  76.67  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...
# 8   45.26     56.58  78.48  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...
# 9   57.89     62.86  77.28  {'learning_rate': 0.1, 'max_depth': 4, 'n_esti...
# 10  60.00     63.69  75.63  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 11  62.11     64.84  76.85  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 12  62.11     66.29  77.29  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 13  55.79     63.10  79.10  {'learning_rate': 0.01, 'max_depth': 4, 'n_est...
# 14  62.11     65.19  79.15  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...
# 15  63.16     67.80  80.65  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 16  67.37     69.57  79.97  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 17  67.37     70.33  84.92  {'learning_rate': 0.01, 'max_depth': 6, 'n_est...
# 18  69.47     71.74  84.39  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 19  71.58     72.73  85.06  {'learning_rate': 0.1, 'max_depth': 4, 'n_esti...
# 20  71.58     72.34  84.02  {'learning_rate': 0.1, 'max_depth': 6, 'n_esti...
# 21  70.53     72.04  83.23  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 22  69.47     72.93  85.32  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...
# 23  69.47     72.93  85.40  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...
# 24  73.68     74.87  84.79  {'learning_rate': 0.1, 'max_depth': 4, 'n_esti...
# 25  72.63     74.59  84.37  {'learning_rate': 0.1, 'max_depth': 6, 'n_esti...
# 26  81.05     81.91  91.38  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 27  78.95     80.21  90.90  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 28  76.84     80.22  91.61  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 29  80.00     81.72  90.96  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 30  80.00     81.72  91.31  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 31  78.95     80.21  92.14  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 32  78.95     80.21  91.46  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 33  75.79     81.82  92.98  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 34  75.79     81.36  94.22  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...
# 35  75.79     81.36  94.19  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...
# 36  74.74     80.68  93.76  {'learning_rate': 0.1, 'max_depth': 4, 'n_esti...
# 37  77.89     81.77  93.88  {'learning_rate': 0.1, 'max_depth': 6, 'n_esti...
# 38  76.84     82.49  93.55  {'learning_rate': 0.1, 'max_depth': 4, 'n_esti...
# 39  82.11     84.78  94.52  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 40  80.00     84.92  94.13  {'learning_rate': 0.1, 'max_depth': 4, 'n_esti...
# 41  80.00     84.44  94.29  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...
# 42  83.16     85.87  94.63  {'learning_rate': 0.1, 'max_depth': 6, 'n_esti...
# 43  83.16     86.34  94.96  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 44  81.05     85.08  94.94  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...
# 45  81.05     84.62  94.58  {'learning_rate': 0.1, 'max_depth': 6, 'n_esti...
# 46  81.05     84.15  94.66  {'learning_rate': 0.1, 'max_depth': 6, 'n_esti...
# 47  78.95     83.33  94.84  {'learning_rate': 0.01, 'max_depth': 6, 'n_est...
# 48  81.05     83.70  94.11  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 49  80.00     84.44  94.15  {'learning_rate': 0.1, 'max_depth': 6, 'n_esti...
# 50  80.00     83.98  94.43  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...

# %%
df_result_val.to_csv("../Results/XGBoosting_val_comp.csv")

# %%
params_op = df_result_val[df_result_val['ACC'] == max(df_result_val['ACC'])]["Params"].values[0]
gene_op = df_result_val[df_result_val['ACC'] == max(df_result_val['ACC'])]["Gene"].values
params_op
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.5}

# %%
from xgboost import XGBClassifier
best_model = XGBClassifier(n_estimators= 100, max_depth= 3, learning_rate=0.1, subsample= 0.5)
i = 13
best_model.fit(x_train_sc[:,:i],y_train)
y_pred = best_model.predict((x_test_sc[:,:i]))
y_prob = best_model.predict_proba((x_test_sc[:,:i]))[:,1]
acc = accuracy_score(y_test,y_pred)
evaluate = confusion_matrix_scorer(None,None,y_test,y_pred,y_prob)

# %%
result_eva = [[gene_op[0],'%.2f'%(evaluate["acc"]*100),'%.2f'%(evaluate["precision"]*100),'%.2f'%(evaluate["specificity"]*100),'%.2f'%(evaluate["sensitivity"]*100),'%.2f'%(evaluate["f1_score"]*100),'%.2f'%(evaluate["auc"]*100),params_op]]
result = pd.DataFrame(result_eva)
result.columns = ['Gene','ACC','Precision','Sp','Sn','f1_Score','AUC','Parameter']
result
# Out:
#                                                 Gene    ACC Precision     Sp  \
# 0  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  86.12     84.93  91.47
#
#       Sn f1_Score    AUC                                          Parameter
# 0  77.50    81.05  93.67  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...

# %%
result.to_csv("../Results/XGBoosting_test_comp.csv")
