# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("../data_preprocessing/data_preprocessing_combine_finnal.csv")
df.drop(columns=['Unnamed: 0'],inplace=True)
df
# Out:
#           Sample     OR1E2     TUSC5  AASDHPPT      AQP7      LIPK     AIPL1  \
# 0     GSM3076582  6.581220  6.688305  6.741024  6.740158  6.450692  6.921650
# 1     GSM3076584  6.469258  6.489694  6.930636  6.528830  6.387897  6.784161
# 2     GSM3076586  6.435401  6.397368  7.043787  6.592287  6.527094  6.674845
# 3     GSM3076588  6.649721  6.528980  6.909826  6.549388  6.467235  6.744593
# 4     GSM3076590  6.314682  6.645236  6.984183  6.690670  6.525904  6.790555
# ...          ...       ...       ...       ...       ...       ...       ...
# 1037  GSM3080176  6.478888  6.652626  6.688672  6.432780  6.538850  6.513969
# 1038  GSM3080177  6.421064  6.638464  7.083479  6.615356  6.417832  6.607272
# 1039  GSM3080178  6.485310  6.660722  7.144724  6.450517  6.465697  6.587126
# 1040  GSM3080179  6.503056  6.677416  6.967806  6.596454  6.511638  6.499526
# 1041  GSM3080180  6.461564  6.641557  7.033320  6.564129  6.470293  6.596996
#
#       XM_373670  C1ORF187     FNBP4  ...    SLC7A5   ONECUT2   GPR172B  \
# 0      6.903018  6.705819  8.778815  ...  7.859030  6.583751  6.508321
# 1      7.106279  6.689787  9.312376  ...  8.305035  6.619171  6.429319
# 2      6.956772  6.691307  9.561462  ...  7.614169  6.567367  6.454378
# 3      6.996439  6.716519  9.289106  ...  8.185950  6.581991  6.446086
# 4      6.770173  6.651434  9.547892  ...  7.631164  6.560580  6.612198
# ...         ...       ...       ...  ...       ...       ...       ...
# 1037   6.792356  6.659403  7.830163  ...  7.718400  6.618477  6.657382
# 1038   6.900284  6.607437  8.485269  ...  7.590302  6.582872  6.714842
# 1039   6.884740  6.702011  8.659146  ...  7.487854  6.626871  6.568408
# 1040   7.049166  6.691996  8.078439  ...  7.560744  6.649050  6.621918
# 1041   6.900440  6.619374  8.573955  ...  7.586528  6.598685  6.590518
#
#            AGK   TMEM14B     PIPOX      MND1  ATP6V0A4   PPP1R3C  label
# 0     6.959389  7.092078  6.508321  6.581220  6.528690  6.508321    1.0
# 1     7.275144  7.670455  6.449538  6.429319  6.513083  6.623958    1.0
# 2     7.336031  7.757373  6.664901  6.527094  6.567624  6.543505    1.0
# 3     7.108844  7.338425  6.424871  6.424871  6.495675  6.446086    0.0
# 4     7.436369  7.972051  6.450317  6.560841  6.527148  6.578445    0.0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1037  6.832535  7.562649  6.457882  6.518911  6.625712  6.633629    0.0
# 1038  6.942387  8.308571  6.480475  6.448664  6.533901  6.629859    0.0
# 1039  7.170392  8.254397  6.532769  6.504432  6.562634  6.606571    0.0
# 1040  7.004240  7.914436  6.576983  6.393231  6.530213  6.927922    0.0
# 1041  7.046274  8.343013  6.551523  6.513603  6.537195  6.583399    1.0
#
# [1042 rows x 21031 columns]

# %%
feature = pd.read_csv('../Feature_selection/feature_ranks.csv')
feature
# Out:
#          Gene      coef
# 0    SLC25A20  1.037430
# 1        DMKN  0.898798
# 2       MFSD4  0.888019
# 3    KIAA1407  0.885901
# 4       ATP5J  0.885820
# 5        ESR2  0.829024
# 6     SNORD68  0.704249
# 7       CTCFL  0.697671
# 8        SLA2  0.692866
# 9        KLK8  0.691708
# 10      IQCF3  0.674324
# 11      SSTR5  0.652845
# 12   BG572427  0.641018
# 13      LUZP5  0.622320
# 14       MAEL  0.599621
# 15    C9ORF80  0.597641
# 16  C21ORF119  0.596703
# 17    SLC11A1  0.586891
# 18      F2RL2  0.540881
# 19       CGB7  0.530138
# 20       DGKE  0.512537
# 21      OR6Y1  0.505157
# 22     HDAC10  0.491177
# 23   BF577257  0.490556
# 24     CYP2D6  0.468757
# 25   MGC13098  0.460773
# 26  LOC651436  0.456718
# 27       TYMS  0.454931
# 28     RHBDD2  0.418772
# 29    FAM19A2  0.410266
# 30     TMEM56  0.396017
# 31     PARD6A  0.393060
# 32     DEPDC4  0.383476
# 33      IL2RB  0.381343
# 34      FAM3D  0.362551
# 35  LOC442204  0.349947
# 36  LOC651476  0.339251
# 37   BC029043  0.328190
# 38   BX093678  0.321640
# 39       PPID  0.291284
# 40    SLC40A1  0.283619
# 41      RBPJL  0.263119
# 42     PPP3R1  0.256965
# 43   FLJ41170  0.256368
# 44      ECAT1  0.249634
# 45   FLJ39061  0.249359
# 46   AK094576  0.232647
# 47       BCL9  0.230321
# 48     EFCAB2  0.197913
# 49      OR1I1  0.170732
# 50       GJA4  0.077651

# %%
y = df['label']

# %%
df_important = df[feature["Gene"]]
df_important
# Out:
#       SLC25A20      DMKN     MFSD4  KIAA1407     ATP5J      ESR2   SNORD68  \
# 0     7.564375  6.525967  6.525032  6.626689  8.169702  6.616488  6.670997
# 1     7.560086  6.537213  6.655353  6.586336  8.212939  6.585217  6.733241
# 2     7.838981  6.516547  6.484780  6.694373  8.399629  6.680588  6.760191
# 3     7.072620  6.559851  6.508151  6.590012  8.327068  6.629900  6.611076
# 4     7.457290  6.594837  6.518612  6.763870  8.552317  6.551899  7.091630
# ...        ...       ...       ...       ...       ...       ...       ...
# 1037  6.956738  6.538661  6.557583  6.583398  7.120349  6.593971  6.920592
# 1038  7.392408  6.546795  6.597736  6.690660  7.540171  6.542025  6.883567
# 1039  7.202829  6.546471  6.613679  6.603059  7.507369  6.568026  7.037980
# 1040  7.307079  6.572414  6.603748  6.520534  7.307165  6.522085  7.023153
# 1041  7.125904  6.549023  6.708699  6.686823  7.630988  6.630469  6.850642
#
#          CTCFL      SLA2      KLK8  ...     RBPJL     PPP3R1  FLJ41170  \
# 0     6.527108  7.356927  6.545089  ...  6.618013  10.104458  6.508321
# 1     6.489694  7.280015  6.626963  ...  6.750361  10.153788  6.548088
# 2     6.607421  7.269385  6.614125  ...  6.576834   9.843453  6.509526
# 3     6.528980  7.473021  6.638702  ...  6.669343   9.927702  6.446086
# 4     6.578445  7.118522  6.585570  ...  6.488929  10.077513  6.543316
# ...        ...       ...       ...  ...       ...        ...       ...
# 1037  6.475672  7.106789  6.605116  ...  6.733956   8.083167  6.591486
# 1038  6.462322  7.209962  6.500573  ...  6.637949   8.231499  6.591183
# 1039  6.439943  6.941301  6.578945  ...  6.783281   8.141402  6.644052
# 1040  6.401485  7.052313  6.561615  ...  6.682789   8.372051  6.706020
# 1041  6.566462  6.918804  6.560460  ...  6.602067   8.058610  6.717784
#
#          ECAT1  FLJ39061  AK094576      BCL9    EFCAB2     OR1I1      GJA4
# 0     6.827648  6.686500  6.618013  6.959389  6.581220  6.545113  6.618013
# 1     6.733241  6.508521  6.528830  7.055799  6.449538  6.697290  6.469258
# 2     6.622423  6.621851  6.543505  7.156384  6.560226  6.416332  6.607421
# 3     6.549388  6.590456  6.707130  7.328471  6.424871  6.403355  6.403355
# 4     6.612198  6.569577  6.675939  7.286396  6.543316  6.543316  6.488929
# ...        ...       ...       ...       ...       ...       ...       ...
# 1037  6.620220  6.535341  6.733779  7.491137  6.543771  6.552586  6.608870
# 1038  6.667317  6.603987  6.838434  7.203468  6.680996  6.503975  6.589710
# 1039  6.699028  6.569459  6.733987  7.270375  6.652864  6.523572  6.465286
# 1040  6.698650  6.583890  6.772120  7.426019  6.648444  6.449075  6.613935
# 1041  6.760783  6.556932  6.762324  7.179075  6.522553  6.498568  6.677579
#
# [1042 rows x 51 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df_important,y,test_size=0.1,random_state=11,stratify=y,shuffle=True)
print(f"Train shape:{x_train.shape}")
print(f"Test shape:{x_test.shape}")
# Out:
# Train shape:(833, 51)
# Test shape:(209, 51)

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x_train_sc = scale.fit_transform(x_train)
x_test_sc = scale.transform(x_test)

# %%
list_feature = feature['Gene']
list_feature
# Out:
# 0      SLC25A20
# 1          DMKN
# 2         MFSD4
# 3      KIAA1407
# 4         ATP5J
# 5          ESR2
# 6       SNORD68
# 7         CTCFL
# 8          SLA2
# 9          KLK8
# 10        IQCF3
# 11        SSTR5
# 12     BG572427
# 13        LUZP5
# 14         MAEL
# 15      C9ORF80
# 16    C21ORF119
# 17      SLC11A1
# 18        F2RL2
# 19         CGB7
# 20         DGKE
# 21        OR6Y1
# 22       HDAC10
# 23     BF577257
# 24       CYP2D6
# 25     MGC13098
# 26    LOC651436
# 27         TYMS
# 28       RHBDD2
# 29      FAM19A2
# 30       TMEM56
# 31       PARD6A
# 32       DEPDC4
# 33        IL2RB
# 34        FAM3D
# 35    LOC442204
# 36    LOC651476
# 37     BC029043
# 38     BX093678
# 39         PPID
# 40      SLC40A1
# 41        RBPJL
# 42       PPP3R1
# 43     FLJ41170
# 44        ECAT1
# 45     FLJ39061
# 46     AK094576
# 47         BCL9
# 48       EFCAB2
# 49        OR1I1
# 50         GJA4
# Name: Gene, dtype: object

# %%
ranks = []
for i in range(len(list_feature)):
    arr = []
    for j in range(i+1):
        arr.append(list_feature[j])
    ranks.append(arr)
ranks
# Out:
# [['SLC25A20'],
#  ['SLC25A20', 'DMKN'],
#  ['SLC25A20', 'DMKN', 'MFSD4'],
#  ['SLC25A20', 'DMKN', 'MFSD4', 'KIAA1407'],
#  ['SLC25A20', 'DMKN', 'MFSD4', 'KIAA1407', 'ATP5J'],
#  ['SLC25A20', 'DMKN', 'MFSD4', 'KIAA1407', 'ATP5J', 'ESR2'],
#  ['SLC25A20', 'DMKN', 'MFSD4', 'KIAA1407', 'ATP5J', 'ESR2', 'SNORD68'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL',
#   'PPP3R1'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL',
#   'PPP3R1',
#   'FLJ41170'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL',
#   'PPP3R1',
#   'FLJ41170',
#   'ECAT1'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL',
#   'PPP3R1',
#   'FLJ41170',
#   'ECAT1',
#   'FLJ39061'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL',
#   'PPP3R1',
#   'FLJ41170',
#   'ECAT1',
#   'FLJ39061',
#   'AK094576'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL',
#   'PPP3R1',
#   'FLJ41170',
#   'ECAT1',
#   'FLJ39061',
#   'AK094576',
#   'BCL9'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL',
#   'PPP3R1',
#   'FLJ41170',
#   'ECAT1',
#   'FLJ39061',
#   'AK094576',
#   'BCL9',
#   'EFCAB2'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL',
#   'PPP3R1',
#   'FLJ41170',
#   'ECAT1',
#   'FLJ39061',
#   'AK094576',
#   'BCL9',
#   'EFCAB2',
#   'OR1I1'],
#  ['SLC25A20',
#   'DMKN',
#   'MFSD4',
#   'KIAA1407',
#   'ATP5J',
#   'ESR2',
#   'SNORD68',
#   'CTCFL',
#   'SLA2',
#   'KLK8',
#   'IQCF3',
#   'SSTR5',
#   'BG572427',
#   'LUZP5',
#   'MAEL',
#   'C9ORF80',
#   'C21ORF119',
#   'SLC11A1',
#   'F2RL2',
#   'CGB7',
#   'DGKE',
#   'OR6Y1',
#   'HDAC10',
#   'BF577257',
#   'CYP2D6',
#   'MGC13098',
#   'LOC651436',
#   'TYMS',
#   'RHBDD2',
#   'FAM19A2',
#   'TMEM56',
#   'PARD6A',
#   'DEPDC4',
#   'IL2RB',
#   'FAM3D',
#   'LOC442204',
#   'LOC651476',
#   'BC029043',
#   'BX093678',
#   'PPID',
#   'SLC40A1',
#   'RBPJL',
#   'PPP3R1',
#   'FLJ41170',
#   'ECAT1',
#   'FLJ39061',
#   'AK094576',
#   'BCL9',
#   'EFCAB2',
#   'OR1I1',
#   'GJA4']]

# %%
from sklearn.metrics import confusion_matrix,roc_auc_score
def confusion_matrix_scorer(clf=None,X=None, y=None,y_pred=None,y_prob=None):
    if clf != None:
        y_pred = clf.predict(X)
        y_prob = clf.predict_proba(X)[:,1]
    auc = roc_auc_score(y,y_prob)
    tn,fp,fn,tp = confusion_matrix(y,y_pred).ravel()
    acc = (tp+tn) / (tp+fp+fn+tn)
    precision = tp/(tp+fp)
    specificity = tn/(tn+fp)
    sensitivity = tp / (tp+fn)
    f1_score = (2*tp)/(2*tp+fp+fn)
    return {'acc':acc,'precision':precision,'specificity':specificity,'sensitivity':sensitivity,'f1_score':f1_score,'auc':auc}

# %%
NUMBER_FOLD = 4
def create_df_val(rank,rs_cv):
    df_val = {
        "ACC":[],
        "precision":[],
        "specificity":[],
        "sensitivity":[],
        "f1_score":[],
        "AUC":[],
        "params":[]
    }
    for i in range(NUMBER_FOLD):
        str_label = f"split{i}"
        df_val["ACC"].append(np.array(rs_cv[str_label+"_test_acc"]))
        df_val["precision"].append(rs_cv[str_label+"_test_precision"])
        df_val["specificity"].append(rs_cv[str_label+"_test_specificity"])
        df_val["sensitivity"].append(rs_cv[str_label+"_test_sensitivity"])
        df_val["f1_score"].append(rs_cv[str_label+"_test_f1_score"])
        df_val["AUC"].append(rs_cv[str_label+"_test_auc"])
        df_val["params"].append(rs_cv["params"])
    df_val["ACC"] = np.array(df_val["ACC"] ).flatten()
    df_val["precision"] = np.array(df_val["precision"] ).flatten()
    df_val["specificity"] = np.array(df_val["specificity"] ).flatten()
    df_val["sensitivity"] = np.array(df_val["sensitivity"] ).flatten()
    df_val["f1_score"] = np.array(df_val["f1_score"] ).flatten()
    df_val["AUC"] = np.array(df_val["AUC"] ).flatten()
    df_val["params"] = np.array(df_val["params"] ).flatten()
    df_combine_val = pd.DataFrame(df_val).dropna(axis=0).sort_values(by="ACC",ascending=False)
    if df_combine_val.shape[0]>0:
        gene_top =  df_combine_val.iloc[0,:].values
        return [rank,gene_top[0],gene_top[1],gene_top[2],gene_top[3],gene_top[4],gene_top[5],gene_top[6]]
    else:
        return []

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV,StratifiedShuffleSplit

model = DecisionTreeClassifier(random_state=11)
params = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'splitter':['best', 'random'],
    'max_features':['auto','sqrt','log2'],
}
ss = StratifiedShuffleSplit(n_splits=NUMBER_FOLD,test_size=0.3,random_state=11)
grid_search = GridSearchCV(estimator=model, param_grid=params, 
                              cv=ss, verbose=2, return_train_score=True,refit=False,scoring=confusion_matrix_scorer)
ls_result = []
for i,rank in enumerate(ranks):
    grid_model = grid_search.fit(x_train_sc[:,:i+1],y_train)
    rs_cv = grid_model.cv_results_
    ls_result.append(create_df_val(rank,rs_cv))

# %%
df_result_val = pd.DataFrame(ls_result)
df_result_val.columns = ["Gene","ACC","Precision","Sp","Sn","F1_score","AUC","Params"]
df_result_val.iloc[:,1:7] = round(df_result_val.iloc[:,1:7] * 100,2)
df_result_val
# Out:
#                                                  Gene   ACC  Precision     Sp  \
# 0                                          [SLC25A20]  58.8      46.08  64.52
# 1                                    [SLC25A20, DMKN]  61.6      49.46  69.68
# 2                             [SLC25A20, DMKN, MFSD4]  62.4      50.56  71.61
# 3                   [SLC25A20, DMKN, MFSD4, KIAA1407]  64.0      52.53  69.68
# 4            [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J]  70.4      61.80  78.06
# 5      [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2]  65.2      54.17  71.61
# 6   [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  68.8      57.94  70.97
# 7   [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  68.4      59.30  77.42
# 8   [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  70.8      61.70  76.77
# 9   [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  71.2      62.92  78.71
# 10  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  64.8      53.27  67.74
# 11  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  68.0      58.82  77.42
# 12  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  67.2      56.44  71.61
# 13  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  64.8      54.02  74.19
# 14  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  67.2      56.07  69.68
# 15  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  70.0      61.36  78.06
# 16  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  67.6      57.78  75.48
# 17  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  66.4      55.56  71.61
# 18  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  68.8      58.10  71.61
# 19  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  66.4      55.67  72.26
# 20  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  68.8      58.42  72.90
# 21  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  65.6      55.29  75.48
# 22  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  68.8      58.76  74.19
# 23  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  70.8      60.78  74.19
# 24  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  67.6      57.45  74.19
# 25  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  68.0      57.43  72.26
# 26  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  72.4      65.12  80.65
# 27  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  71.6      63.04  78.06
# 28  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  71.2      63.53  80.00
# 29  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  71.2      60.95  73.55
# 30  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  67.6      57.78  75.48
# 31  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  70.0      61.36  78.06
# 32  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  71.6      63.33  78.71
# 33  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.8      67.39  80.65
# 34  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  64.8      53.93  73.55
# 35  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  73.2      64.58  78.06
# 36  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  72.8      64.84  79.35
# 37  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  70.8      61.96  77.42
# 38  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  70.4      61.29  76.77
# 39  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.4      67.82  81.94
# 40  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  70.8      61.00  74.84
# 41  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  72.0      63.16  77.42
# 42  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.4      66.32  79.35
# 43  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.0      66.30  80.00
# 44  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  70.8      61.22  75.48
# 45  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  73.2      68.42  84.52
# 46  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  71.6      63.64  79.35
# 47  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  72.8      63.11  75.48
# 48  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  74.0      66.67  80.65
# 49  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  72.4      68.06  85.16
# 50  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  75.2      65.42  76.13
#
#        Sn  F1_score    AUC                                             Params
# 0   49.47     47.72  56.99  {'criterion': 'entropy', 'max_features': 'sqrt...
# 1   48.42     48.94  59.05  {'criterion': 'log_loss', 'max_features': 'sqr...
# 2   47.37     48.91  59.49  {'criterion': 'log_loss', 'max_features': 'log...
# 3   54.74     53.61  62.21  {'criterion': 'log_loss', 'max_features': 'log...
# 4   57.89     59.78  67.98  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 5   54.74     54.45  63.17  {'criterion': 'gini', 'max_features': 'log2', ...
# 6   65.26     61.39  68.12  {'criterion': 'log_loss', 'max_features': 'log...
# 7   53.68     56.35  65.55  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 8   61.05     61.38  68.91  {'criterion': 'entropy', 'max_features': 'sqrt...
# 9   58.95     60.87  68.83  {'criterion': 'gini', 'max_features': 'log2', ...
# 10  60.00     56.44  63.87  {'criterion': 'log_loss', 'max_features': 'log...
# 11  52.63     55.56  65.03  {'criterion': 'log_loss', 'max_features': 'log...
# 12  60.00     58.16  65.81  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 13  49.47     51.65  61.83  {'criterion': 'gini', 'max_features': 'log2', ...
# 14  63.16     59.41  66.42  {'criterion': 'log_loss', 'max_features': 'log...
# 15  56.84     59.02  67.45  {'criterion': 'log_loss', 'max_features': 'log...
# 16  54.74     56.22  65.11  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 17  57.89     56.70  64.75  {'criterion': 'entropy', 'max_features': 'sqrt...
# 18  64.21     61.00  67.91  {'criterion': 'log_loss', 'max_features': 'log...
# 19  56.84     56.25  64.55  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 20  62.11     60.20  67.50  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 21  49.47     52.22  62.48  {'criterion': 'entropy', 'max_features': 'sqrt...
# 22  60.00     59.38  67.10  {'criterion': 'gini', 'max_features': 'log2', ...
# 23  65.26     62.94  69.73  {'criterion': 'gini', 'max_features': 'log2', ...
# 24  56.84     57.14  65.52  {'criterion': 'entropy', 'max_features': 'sqrt...
# 25  61.05     59.18  66.66  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 26  58.95     61.88  69.80  {'criterion': 'gini', 'max_features': 'log2', ...
# 27  61.05     62.03  69.56  {'criterion': 'log_loss', 'max_features': 'sqr...
# 28  56.84     60.00  68.42  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 29  67.37     64.00  70.46  {'criterion': 'log_loss', 'max_features': 'sqr...
# 30  54.74     56.22  65.11  {'criterion': 'log_loss', 'max_features': 'log...
# 31  56.84     59.02  67.45  {'criterion': 'log_loss', 'max_features': 'log...
# 32  60.00     61.62  69.35  {'criterion': 'log_loss', 'max_features': 'log...
# 33  65.26     66.31  72.95  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 34  50.53     52.17  62.04  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 35  65.26     64.92  71.66  {'criterion': 'entropy', 'max_features': 'sqrt...
# 36  62.11     63.44  70.73  {'criterion': 'entropy', 'max_features': 'log2...
# 37  60.00     60.96  68.71  {'criterion': 'log_loss', 'max_features': 'log...
# 38  60.00     60.64  68.39  {'criterion': 'log_loss', 'max_features': 'log...
# 39  62.11     64.84  72.02  {'criterion': 'log_loss', 'max_features': 'sqr...
# 40  64.21     62.56  69.52  {'criterion': 'log_loss', 'max_features': 'sqr...
# 41  63.16     63.16  70.29  {'criterion': 'gini', 'max_features': 'log2', ...
# 42  66.32     66.32  72.84  {'criterion': 'log_loss', 'max_features': 'sqr...
# 43  64.21     65.24  72.11  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 44  63.16     62.18  69.32  {'criterion': 'log_loss', 'max_features': 'log...
# 45  54.74     60.82  69.63  {'criterion': 'log_loss', 'max_features': 'sqr...
# 46  58.95     61.20  69.15  {'criterion': 'log_loss', 'max_features': 'log...
# 47  68.42     65.66  71.95  {'criterion': 'log_loss', 'max_features': 'log...
# 48  63.16     64.86  71.90  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 49  51.58     58.68  68.37  {'criterion': 'log_loss', 'max_features': 'sqr...
# 50  73.68     69.31  74.91  {'criterion': 'log_loss', 'max_features': 'sqr...

# %%
df_result_val.to_csv("../Results/DecisionTree_val.csv")

# %%
params_op = df_result_val[df_result_val['ACC'] == max(df_result_val['ACC'])]["Params"].values[0]
gene_op = df_result_val[df_result_val['ACC'] == max(df_result_val['ACC'])]["Gene"].values
params_op
# Out:
# {'criterion': 'log_loss', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
best_model = DecisionTreeClassifier(criterion= params_op['criterion'], splitter= params_op['splitter'], max_features= params_op['max_features'],random_state=11)
i = len(gene_op[0])
best_model.fit(x_train_sc[:,:i],y_train)
y_pred = best_model.predict((x_test_sc[:,:i]))
y_prob = best_model.predict_proba((x_test_sc[:,:i]))[:,1]
acc = accuracy_score(y_test,y_pred)
evaluate = confusion_matrix_scorer(None,None,y_test,y_pred,y_prob)

# %%
result_eva = [[gene_op[0],'%.2f'%(evaluate["acc"]*100),'%.2f'%(evaluate["precision"]*100),'%.2f'%(evaluate["specificity"]*100),'%.2f'%(evaluate["sensitivity"]*100),'%.2f'%(evaluate["f1_score"]*100),'%.2f'%(evaluate["auc"]*100),params_op]]
result = pd.DataFrame(result_eva)
result.columns = ['Gene','ACC','Precision','Sp','Sn','f1_Score','AUC','Parameter']
result
# Out:
#                                                 Gene    ACC Precision     Sp  \
# 0  [SLC25A20, DMKN, MFSD4, KIAA1407, ATP5J, ESR2,...  76.08     68.29  79.84
#
#       Sn f1_Score    AUC                                          Parameter
# 0  70.00    69.14  74.92  {'criterion': 'log_loss', 'max_features': 'sqr...

# %%
result.to_csv("../Results/DecisionTree_test.csv")
