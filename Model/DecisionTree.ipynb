# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("../Feature_selection/data_preprocessing_combine_finnal.csv")
df.drop(columns='Unnamed: 0',inplace=True)
df.head()
# Out:
#        Sample     OR1E2     TUSC5  AASDHPPT      AQP7      LIPK     AIPL1  \
# 0  GSM3076582  6.581220  6.688305  6.741024  6.740158  6.450692  6.921650
# 1  GSM3076584  6.469258  6.489694  6.930636  6.528830  6.387897  6.784161
# 2  GSM3076586  6.435401  6.397368  7.043787  6.592287  6.527094  6.674845
# 3  GSM3076588  6.649721  6.528980  6.909826  6.549388  6.467235  6.744593
# 4  GSM3076590  6.314682  6.645236  6.984183  6.690670  6.525904  6.790555
#
#    XM_373670  C1ORF187     FNBP4  ...    SLC7A5   ONECUT2   GPR172B       AGK  \
# 0   6.903018  6.705819  8.778815  ...  7.859030  6.583751  6.508321  6.959389
# 1   7.106279  6.689787  9.312376  ...  8.305035  6.619171  6.429319  7.275144
# 2   6.956772  6.691307  9.561462  ...  7.614169  6.567367  6.454378  7.336031
# 3   6.996439  6.716519  9.289106  ...  8.185950  6.581991  6.446086  7.108844
# 4   6.770173  6.651434  9.547892  ...  7.631164  6.560580  6.612198  7.436369
#
#     TMEM14B     PIPOX      MND1  ATP6V0A4   PPP1R3C  label
# 0  7.092078  6.508321  6.581220  6.528690  6.508321    1.0
# 1  7.670455  6.449538  6.429319  6.513083  6.623958    1.0
# 2  7.757373  6.664901  6.527094  6.567624  6.543505    1.0
# 3  7.338425  6.424871  6.424871  6.495675  6.446086    0.0
# 4  7.972051  6.450317  6.560841  6.527148  6.578445    0.0
#
# [5 rows x 21031 columns]

# %%
feature = pd.read_csv('./feature_ranks_mmpc.csv')
feature.head()
# Out:
#         Gene
# 0       IL18
# 1     FER1L3
# 2   AL157484
# 3     VPS13C
# 4  LOC653591

# %%
y = df['label']

# %%
df_important = df[feature["Gene"]]
df_important
# Out:
#            IL18    FER1L3  AL157484    VPS13C  LOC653591      IL2RB     ABCA1  \
# 0     12.903117  6.966753  8.363024  7.016656   6.581220   8.604720  8.851976
# 1     12.995269  6.999537  8.917389  6.976836   6.660894   8.659305  8.789759
# 2     13.005459  7.077072  8.731037  7.089554   6.738754   9.133012  8.904024
# 3     13.049241  7.689700  9.575752  7.498168   6.688580   8.830177  8.659305
# 4     12.663681  7.304761  9.020216  7.125501   6.918910   9.090617  8.692033
# ...         ...       ...       ...       ...        ...        ...       ...
# 1037  13.339397  6.880409  8.824455  7.238020   6.763851   9.449836  6.744091
# 1038  13.177152  6.824118  8.293475  7.007228   6.845326   9.538136  8.109153
# 1039  13.305206  6.942745  8.875184  7.117615   6.899184  10.490795  7.486759
# 1040  13.511535  6.772230  8.817710  7.183229   7.015890   9.402771  7.790773
# 1041  13.090953  6.920923  8.371567  7.106119   6.744242   9.630275  7.961533
#
#         ERVWE1      LDLR     SYTL3  ...     STAU2  MGC24103    RNF165  \
# 0     6.833610  7.592268  9.173028  ...  6.827648  6.809931  7.761827
# 1     6.649225  7.768980  8.905537  ...  6.850744  6.733241  7.456616
# 2     6.768288  7.499118  8.685605  ...  7.023531  6.691402  7.462702
# 3     6.968542  7.674013  8.739087  ...  6.487721  6.854683  7.475896
# 4     6.743386  7.620191  8.389135  ...  7.000783  6.675939  7.206908
# ...        ...       ...       ...  ...       ...       ...       ...
# 1037  6.609922  7.796124  8.093325  ...  6.906134  7.044096  7.132844
# 1038  6.703550  7.635214  8.764983  ...  6.802736  6.766979  7.035870
# 1039  6.693923  7.809693  8.194276  ...  6.745716  6.940422  7.614972
# 1040  6.680400  7.656712  8.202512  ...  6.725860  6.999837  7.578806
# 1041  6.652014  7.624383  8.131298  ...  6.943168  6.989430  7.148973
#
#       BC080552  AK124771     GPR97     SSTR5     MYO5C  LOC730656      NRG1
# 0     7.030301  6.921300  8.896062  6.688305  6.740158   6.581220  6.546042
# 1     6.917383  7.537789  8.332178  6.449538  6.850744   6.605169  6.641074
# 2     6.770716  7.323996  8.276253  6.527094  6.677929   6.691402  6.671845
# 3     7.283117  6.630636  7.892145  6.487721  6.528980   6.487721  6.599425
# 4     6.938120  7.127580  7.851027  6.469428  6.718180   6.392738  6.531331
# ...        ...       ...       ...       ...       ...        ...       ...
# 1037  7.835880  6.778497  7.747274  6.502977  6.745285   6.551610  6.701982
# 1038  7.158885  7.107113  7.971264  6.355886  6.741811   6.576480  6.664663
# 1039  7.454734  6.917895  7.668293  6.561785  6.831080   6.593668  6.642215
# 1040  7.566920  6.962266  7.698907  6.575676  6.661368   6.632561  6.601802
# 1041  7.580032  6.957571  7.476737  6.458386  6.684585   6.714125  6.634755
#
# [1042 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df_important,y,test_size=0.3,random_state=11)
print(f"Train shape:{x_train.shape}")
print(f"Test shape:{x_test.shape}")
# Out:
# Train shape:(729, 24)
# Test shape:(313, 24)

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x_train_sc = scale.fit_transform(x_train)
x_test_sc = scale.transform(x_test)

# %%
list_feature = feature['Gene']
list_feature
# Out:
# 0          IL18
# 1        FER1L3
# 2      AL157484
# 3        VPS13C
# 4     LOC653591
# 5         IL2RB
# 6         ABCA1
# 7        ERVWE1
# 8          LDLR
# 9         SYTL3
# 10      SLC40A1
# 11         BRI3
# 12        CDAN1
# 13        OLIG2
# 14        STAU2
# 15     MGC24103
# 16       RNF165
# 17     BC080552
# 18     AK124771
# 19        GPR97
# 20        SSTR5
# 21        MYO5C
# 22    LOC730656
# 23         NRG1
# Name: Gene, dtype: object

# %%
ranks = []
for i in range(len(list_feature)):
    arr = []
    for j in range(i+1):
        arr.append(list_feature[j])
    ranks.append(arr)
ranks
# Out:
# [['IL18'],
#  ['IL18', 'FER1L3'],
#  ['IL18', 'FER1L3', 'AL157484'],
#  ['IL18', 'FER1L3', 'AL157484', 'VPS13C'],
#  ['IL18', 'FER1L3', 'AL157484', 'VPS13C', 'LOC653591'],
#  ['IL18', 'FER1L3', 'AL157484', 'VPS13C', 'LOC653591', 'IL2RB'],
#  ['IL18', 'FER1L3', 'AL157484', 'VPS13C', 'LOC653591', 'IL2RB', 'ABCA1'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97',
#   'SSTR5'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97',
#   'SSTR5',
#   'MYO5C'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97',
#   'SSTR5',
#   'MYO5C',
#   'LOC730656'],
#  ['IL18',
#   'FER1L3',
#   'AL157484',
#   'VPS13C',
#   'LOC653591',
#   'IL2RB',
#   'ABCA1',
#   'ERVWE1',
#   'LDLR',
#   'SYTL3',
#   'SLC40A1',
#   'BRI3',
#   'CDAN1',
#   'OLIG2',
#   'STAU2',
#   'MGC24103',
#   'RNF165',
#   'BC080552',
#   'AK124771',
#   'GPR97',
#   'SSTR5',
#   'MYO5C',
#   'LOC730656',
#   'NRG1']]

# %%
from sklearn.metrics import confusion_matrix,roc_auc_score
def cfm(y_test,y_pred,y_prob):
    auc = roc_auc_score(y_test,y_prob)
    tn,fp,fn,tp = confusion_matrix(y_test,y_pred).ravel()
    acc = accuracy_score(y_test,y_pred)
    recall = tp/(tp+fn)
    precision = tp/(tp+fp)
    specificity = tn/(tn+fp)
    sensitivity = tp / (tp+fn)
    f1_score = round((2*recall*precision)/(recall+precision),3)
    return np.array([acc,recall,precision,specificity,sensitivity,f1_score,auc])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

model = DecisionTreeClassifier(random_state=11)
params = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'splitter':['best', 'random'],
    'max_features':['auto','sqrt','log2'],
}
grid_search = GridSearchCV(estimator=model, param_grid=params, 
                              cv=5, verbose=2, return_train_score=True)
acc_max_rank = None
acc_max = -np.inf
result = []
best_paramet = None
for i,rank in enumerate(ranks):
    grid_search.fit(x_train_sc[:,:i+1],y_train)
    best_parameters = grid_search.best_params_
    best_model = grid_search.best_estimator_
    best_model.fit(x_train_sc[:,:i+1],y_train)
    y_pred = best_model.predict(x_test_sc[:,:i+1])
    y_prob = best_model.predict_proba((x_test_sc[:,:i+1]))[:,1]
    acc = accuracy_score(y_test,y_pred)
    evaluate = cfm(y_test,y_pred,y_prob)
    result.append([rank,'%.2f'%(evaluate[0]*100)+'%','%.2f'%(evaluate[1]*100)+'%','%.2f'%(evaluate[2]*100)+'%','%.2f'%(evaluate[3]*100)+'%','%.2f'%(evaluate[4]*100)+'%','%.2f'%(evaluate[5]*100)+'%','%.2f'%(evaluate[6]*100)+'%',best_parameters])

# %%
df_result = pd.DataFrame(result)
# acc,recall,precision,specificity,sensitivity,f1_score,auc
df_result.columns = ['Gene','ACC','Recall','Precision','Sp','Sn','f1_Score','AUC','Parameter']
df_result
# Out:
#                                                  Gene     ACC  Recall  \
# 0                                              [IL18]  65.18%  34.23%
# 1                                      [IL18, FER1L3]  63.90%  53.15%
# 2                            [IL18, FER1L3, AL157484]  70.61%  58.56%
# 3                    [IL18, FER1L3, AL157484, VPS13C]  71.57%  65.77%
# 4         [IL18, FER1L3, AL157484, VPS13C, LOC653591]  73.48%  72.97%
# 5   [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  69.97%  58.56%
# 6   [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  78.27%  68.47%
# 7   [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  72.20%  62.16%
# 8   [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  80.83%  76.58%
# 9   [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  77.64%  64.86%
# 10  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  76.36%  59.46%
# 11  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  73.80%  63.96%
# 12  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  74.12%  63.06%
# 13  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  75.08%  65.77%
# 14  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  75.72%  66.67%
# 15  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  79.87%  73.87%
# 16  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  75.08%  65.77%
# 17  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  77.96%  69.37%
# 18  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  77.96%  66.67%
# 19  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  73.48%  56.76%
# 20  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  75.08%  72.97%
# 21  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  70.61%  57.66%
# 22  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  73.16%  61.26%
# 23  [IL18, FER1L3, AL157484, VPS13C, LOC653591, IL...  71.57%  54.95%
#
#    Precision      Sp      Sn f1_Score     AUC  \
# 0     51.35%  82.18%  34.23%   41.10%  65.59%
# 1     49.17%  69.80%  53.15%   51.10%  61.48%
# 2     58.56%  77.23%  58.56%   58.60%  67.89%
# 3     58.87%  74.75%  65.77%   62.10%  70.26%
# 4     60.45%  73.76%  72.97%   66.10%  73.37%
# 5     57.52%  76.24%  58.56%   58.00%  67.40%
# 6     69.72%  83.66%  68.47%   69.10%  76.07%
# 7     60.53%  77.72%  62.16%   61.30%  69.94%
# 8     71.43%  83.17%  76.58%   73.90%  79.87%
# 9     69.90%  84.65%  64.86%   67.30%  74.76%
# 10    69.47%  85.64%  59.46%   64.10%  72.55%
# 11    62.83%  79.21%  63.96%   63.40%  71.59%
# 12    63.64%  80.20%  63.06%   63.30%  71.63%
# 13    64.60%  80.20%  65.77%   65.20%  72.98%
# 14    65.49%  80.69%  66.67%   66.10%  73.68%
# 15    70.69%  83.17%  73.87%   72.20%  78.52%
# 16    64.60%  80.20%  65.77%   65.20%  72.98%
# 17    68.75%  82.67%  69.37%   69.10%  76.02%
# 18    69.81%  84.16%  66.67%   68.20%  75.41%
# 19    64.29%  82.67%  56.76%   60.30%  69.72%
# 20    62.79%  76.24%  72.97%   67.50%  74.61%
# 21    58.72%  77.72%  57.66%   58.20%  67.69%
# 22    62.39%  79.70%  61.26%   61.80%  70.48%
# 23    61.00%  80.69%  54.95%   57.80%  67.82%
#
#                                             Parameter
# 0   {'criterion': 'gini', 'max_features': 'auto', ...
# 1   {'criterion': 'gini', 'max_features': 'auto', ...
# 2   {'criterion': 'entropy', 'max_features': 'auto...
# 3   {'criterion': 'gini', 'max_features': 'auto', ...
# 4   {'criterion': 'entropy', 'max_features': 'auto...
# 5   {'criterion': 'entropy', 'max_features': 'auto...
# 6   {'criterion': 'entropy', 'max_features': 'auto...
# 7   {'criterion': 'entropy', 'max_features': 'auto...
# 8   {'criterion': 'gini', 'max_features': 'auto', ...
# 9   {'criterion': 'gini', 'max_features': 'auto', ...
# 10  {'criterion': 'entropy', 'max_features': 'auto...
# 11  {'criterion': 'entropy', 'max_features': 'auto...
# 12  {'criterion': 'gini', 'max_features': 'auto', ...
# 13  {'criterion': 'entropy', 'max_features': 'auto...
# 14  {'criterion': 'entropy', 'max_features': 'auto...
# 15  {'criterion': 'entropy', 'max_features': 'auto...
# 16  {'criterion': 'entropy', 'max_features': 'auto...
# 17  {'criterion': 'gini', 'max_features': 'auto', ...
# 18  {'criterion': 'entropy', 'max_features': 'auto...
# 19  {'criterion': 'entropy', 'max_features': 'auto...
# 20  {'criterion': 'entropy', 'max_features': 'auto...
# 21  {'criterion': 'entropy', 'max_features': 'auto...
# 22  {'criterion': 'entropy', 'max_features': 'auto...
# 23  {'criterion': 'entropy', 'max_features': 'auto...

# %%
df_result.to_csv("../Results/DecisionTree.csv")
